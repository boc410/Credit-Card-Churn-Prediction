# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %run functions.ipynb

# %%
data = pd.read_csv('../Data/BankChurners.csv')
data.drop(columns=data.columns[-2:], inplace=True)
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  float64
#  14  Total_Revolving_Bal       10127 non-null  int64
#  15  Avg_Open_To_Buy           10127 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  17  Total_Trans_Amt           10127 non-null  int64
#  18  Total_Trans_Ct            10127 non-null  int64
#  19  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  20  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %%
data.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
data.nunique()
# Out:
# CLIENTNUM                   10127
# Attrition_Flag                  2
# Customer_Age                   45
# Gender                          2
# Dependent_count                 6
# Education_Level                 7
# Marital_Status                  4
# Income_Category                 6
# Card_Category                   4
# Months_on_book                 44
# Total_Relationship_Count        6
# Months_Inactive_12_mon          7
# Contacts_Count_12_mon           7
# Credit_Limit                 6205
# Total_Revolving_Bal          1974
# Avg_Open_To_Buy              6813
# Total_Amt_Chng_Q4_Q1         1158
# Total_Trans_Amt              5033
# Total_Trans_Ct                126
# Total_Ct_Chng_Q4_Q1           830
# Avg_Utilization_Ratio         964
# dtype: int64

# %%
data.Attrition_Flag.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
data['churn'] = np.where(data['Attrition_Flag'] == 'Existing Customer', 0, 1).astype(bool)
data.churn.value_counts()
# Out:
# churn
# False    8500
# True     1627
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(data.select_dtypes(include='number').corr(), annot=True, fmt='.2f', ax=ax).set_title('Correlation Matrix')
plt.show()

# %%
data.iloc[:,2:].hist(figsize=(12,10))
plt.show()

# %%
cols = data.columns[1:]

# Number of features (excluding 'churn')
num_features = len(cols) - 1

# Calculate number of rows needed (5 subplots per row)
num_rows = math.ceil(num_features / 5)

# Define the figure size (adjust size as needed)
plt.figure(figsize=(20, num_rows * 4))

# Iterate over each column in the DataFrame
for i, column in enumerate(cols):
    if column != 'churn':
        plt.subplot(num_rows, 5, i+1)  # Create a subplot for each column   

        if data[column].dtype == 'object':  # Check if the column is categorical
            sns.countplot(data=data[data['churn'] == 1], x=column, stat='proportion', color='darkorange', label='Churn', fill=False)
            sns.countplot(data=data[data['churn'] == 0], x=column, stat='proportion', color='blue', label='No churn', fill=False)
        elif column in ['Dependent_count','Total_Relationship_Count','Months_Inactive_12_mons','Contacts_Count_12_mons']: # Check if the column is in list of numeric/categorical
            sns.countplot(data=data[data['churn'] == 1], x=column, stat='proportion', color='darkorange', label='Churn', fill=False)
            sns.countplot(data=data[data['churn'] == 0], x=column, stat='proportion', color='blue', label='No churn', fill=False)
        else:
            # Calculate common bin edges for the feature
            min_value = data[column].min()
            max_value = data[column].max()
            bins = np.linspace(min_value, max_value, 10)  # 10 bins, adjust as needed

            sns.histplot(data=data[data['churn'] == 1], x=column, bins=bins, stat='proportion', element="step", color='darkorange', label='Churn', fill=False)  # Plot for churn=false
            sns.histplot(data=data[data['churn'] == 0], x=column, bins=bins, stat='proportion', element="step", color='blue', label='No churn', fill=False)  # Plot for churn=true
        
        plt.title(f'Distribution of {column}')
        plt.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
data.groupby('churn')['Gender'].value_counts().plot(kind='bar')
plt.show()

# %%
numeric_columns = data.select_dtypes(include='number').columns[1:]
num_features = len(numeric_columns)
fig, axes = plt.subplots(nrows=num_features, ncols=1, figsize=(10, 5 * num_features))

# Create a boxplot for each feature
for i, feature in enumerate(numeric_columns):
    sns.boxplot(x=feature, y='churn', data=data, orient='h', ax=axes[i])
    axes[i].set_title(f'Boxplot of {feature} by Churn')
    axes[i].set_xlabel('Churn')
    axes[i].set_ylabel(feature)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Total revolving amount, total transaction amount, total transaction count, total count change, and average utilization ratio seem to have most significant profile different between churn and non-churn customers.

# %%
churn_counts = data.groupby(['Gender', 'churn']).size().reset_index(name='counts')
sns.catplot(data=churn_counts, kind='bar', x='Gender', y='counts', hue='churn')
plt.title("Count of Churn by Gender")
plt.show()

# %% [markdown]
# Gender doesnt appear to show a significant difference in churn

# %%
fig, axes = plt.subplots(nrows=num_features, ncols=1, figsize=(10, 5 * num_features))

# Create a boxplot for each feature
for i, feature in enumerate(numeric_columns):
    sns.boxplot(x=feature, y='churn', hue='Gender', data=data, orient='h', ax=axes[i])
    axes[i].set_title(f'Boxplot of {feature} by Churn')
    axes[i].set_xlabel('Churn')
    axes[i].set_ylabel(feature)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Profiles for dependent counts, total relationships, inactive months, credit limit, average open to buy, total transaction amounts, total transaction counts, and average utilization ratio all seem impacted by gender.
#
# Gender should be considered as a key feature.

# %%
key_features = ['Total_Revolving_Bal','Total_Trans_Amt','Total_Trans_Ct','Total_Ct_Chng_Q4_Q1','Avg_Utilization_Ratio','Gender']

# %% [markdown]
# **Feature engineering - create categories for numeric values**

# %% [markdown]
# Total_Revolving_Bal

# %%
histplots_by(key_features[0], df=data)
plt.show()

# %%
bins=[-np.inf,0,np.inf]

cut_data(key_features[0],bins,df=data)
plt.show()

# %% [markdown]
# Total_Trans_Amt

# %%
histplots_by(key_features[1], df=data)
plt.show()

# %%
bins=[-np.inf,3000,11000,np.inf]

cut_data(key_features[1],bins,df=data)
plt.show()

# %% [markdown]
# Total_Trans_Ct

# %%
histplots_by(key_features[2], df=data)
plt.show()

# %%
bins=[-np.inf,60,100,np.inf]

cut_data(key_features[2],bins,df=data)
plt.show()

# %% [markdown]
# Total_Ct_Chng_Q4_Q1

# %%
histplots_by(key_features[3], df=data)
plt.show()

# %%
bins=[-np.inf,1,np.inf]

cut_data(key_features[3],bins,df=data)
plt.show()

# %% [markdown]
# Avg_Utilization_Ratio

# %%
histplots_by(key_features[4], df=data)
plt.show()

# %%
bins=[-np.inf,0,.8,np.inf]

cut_data(key_features[4],bins,df=data)
plt.show()

# %% [markdown]
# Review other dimensions for missed trends

# %%
histplots_by('Credit_Limit', df=data)
plt.show()

# %%
histplots_by('Avg_Open_To_Buy', df=data)
plt.show()

# %%
histplots_by('Customer_Age', bw=.5, df=data)
plt.show()

# %%
histplots_by('Dependent_count', bw=.5, df=data)
plt.show()

# %%
histplots_by('Total_Relationship_Count', bw=.5, df=data)
plt.show()

# %%
#add categories for relationship count
bins=[-np.inf,2,np.inf]

cut_data('Total_Relationship_Count',bins, df=data)
plt.show()

# %%
histplots_by('Contacts_Count_12_mon', bw=.5, df=data)
plt.show()

# %%
#add categories for contacts count
bins=[-np.inf,1,np.inf]

cut_data('Contacts_Count_12_mon',bins, df=data)
plt.show()

# %% [markdown]
# Others

# %%
#Group months on book into years
data['years_on_book'] = data['Months_on_book'] // 12

histplots_by('years_on_book', bw=.5, df=data)
plt.show()

# %%
histplots_by('Months_Inactive_12_mon', bw=.5, df=data)
plt.show()

# %%
bins=[-np.inf,0,1,np.inf]

cut_data('Months_Inactive_12_mon',bins, df=data)
plt.show()

# %% [markdown]
# **Get dummy columns for new key categories and drop non-key columns**

# %%
#identify columns to drop from dataset before modelling
drop_cols = ['CLIENTNUM',
             'Attrition_Flag',
             'Total_Revolving_Bal',
             'Total_Trans_Amt',
             'Total_Trans_Ct',
             'Total_Ct_Chng_Q4_Q1',
             'Avg_Utilization_Ratio',
             'Total_Relationship_Count',
             'Contacts_Count_12_mon',
             'Months_Inactive_12_mon',
             'Months_on_book']

data_prep_cols = [col for col in data.columns if col not in drop_cols]

# %%
#seperate columns into 3 categories for further processing
category_cols = ['Gender',
                 'Education_Level',
                 'Marital_Status',
                 'Income_Category',
                 'Card_Category']
range_cols = [col for col in data_prep_cols if 'range' in col]
category_cols = category_cols + range_cols

y_col = 'churn'

other_cols = [col for col in data_prep_cols if col not in category_cols]
other_cols.remove(y_col)

# %%
#create dummy cols
dummy_cols = pd.get_dummies(data[category_cols], drop_first=True)

# %%
#create preprocessed df
data_preprocess = pd.concat([data[other_cols],dummy_cols,data[y_col]], axis=1)
data_preprocess
# Out:
#        Customer_Age  Dependent_count  Credit_Limit  Avg_Open_To_Buy  \
# 0                45                3       12691.0          11914.0
# 1                49                5        8256.0           7392.0
# 2                51                3        3418.0           3418.0
# 3                40                4        3313.0            796.0
# 4                40                3        4716.0           4716.0
# ...             ...              ...           ...              ...
# 10122            50                2        4003.0           2152.0
# 10123            41                2        4277.0           2091.0
# 10124            44                1        5409.0           5409.0
# 10125            30                2        5281.0           5281.0
# 10126            43                2       10388.0           8427.0
#
#        Total_Amt_Chng_Q4_Q1  years_on_book  Gender_M  \
# 0                     1.335              3      True
# 1                     1.541              3     False
# 2                     2.594              3      True
# 3                     1.405              2     False
# 4                     2.175              1      True
# ...                     ...            ...       ...
# 10122                 0.703              3      True
# 10123                 0.804              2      True
# 10124                 0.819              3     False
# 10125                 0.535              3      True
# 10126                 0.703              2     False
#
#        Education_Level_Doctorate  Education_Level_Graduate  \
# 0                          False                     False
# 1                          False                      True
# 2                          False                      True
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 10122                      False                      True
# 10123                      False                     False
# 10124                      False                     False
# 10125                      False                      True
# 10126                      False                      True
#
#        Education_Level_High School  ...  Total_Trans_Ct_range_>60 <=100  \
# 0                             True  ...                           False
# 1                            False  ...                           False
# 2                            False  ...                           False
# 3                             True  ...                           False
# 4                            False  ...                           False
# ...                            ...  ...                             ...
# 10122                        False  ...                           False
# 10123                        False  ...                            True
# 10124                         True  ...                           False
# 10125                        False  ...                            True
# 10126                        False  ...                            True
#
#        Total_Trans_Ct_range_>100  Total_Ct_Chng_Q4_Q1_range_>1  \
# 0                          False                          True
# 1                          False                          True
# 2                          False                          True
# 3                          False                          True
# 4                          False                          True
# ...                          ...                           ...
# 10122                       True                         False
# 10123                      False                         False
# 10124                      False                         False
# 10125                      False                         False
# 10126                      False                         False
#
#        Avg_Utilization_Ratio_range_>0 <=0.8  Avg_Utilization_Ratio_range_>0.8  \
# 0                                      True                             False
# 1                                      True                             False
# 2                                     False                             False
# 3                                      True                             False
# 4                                     False                             False
# ...                                     ...                               ...
# 10122                                  True                             False
# 10123                                  True                             False
# 10124                                 False                             False
# 10125                                 False                             False
# 10126                                  True                             False
#
#        Total_Relationship_Count_range_>2  Contacts_Count_12_mon_range_>1  \
# 0                                   True                            True
# 1                                   True                            True
# 2                                   True                           False
# 3                                   True                           False
# 4                                   True                           False
# ...                                  ...                             ...
# 10122                               True                            True
# 10123                               True                            True
# 10124                               True                            True
# 10125                               True                            True
# 10126                               True                            True
#
#        Months_Inactive_12_mon_range_>0 <=1  Months_Inactive_12_mon_range_>1  \
# 0                                     True                            False
# 1                                     True                            False
# 2                                     True                            False
# 3                                    False                             True
# 4                                     True                            False
# ...                                    ...                              ...
# 10122                                False                             True
# 10123                                False                             True
# 10124                                False                             True
# 10125                                False                             True
# 10126                                False                             True
#
#        churn
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 10122  False
# 10123   True
# 10124   True
# 10125   True
# 10126   True
#
# [10127 rows x 37 columns]

# %% [markdown]
# **Create training/validation datasets**

# %%
temp_data = pd.read_csv('../Data/BankChurners.csv')
temp_data.drop(columns=temp_data.columns[-2:], inplace=True)
eval_data = temp_data.sample(frac=0.7,random_state=0)
val_data = temp_data.drop(eval_data.index)

# %% [markdown]
# **Export datasets as csv**

# %%
data.to_csv('../Data/BankChurnersEnhanced.csv', index=False)

# %%
data_preprocess.to_csv('../Data/BankChurnersPreProcessed.csv', index=False)

# %%
eval_data.to_csv('../Data/BankChurnersEval.csv', index=False)

# %%
val_data.to_csv('../Data/BankChurnersVal.csv', index=False)
