# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix

# %run functions.ipynb

# %%
#import data
orig_data = pd.read_csv('../Data/BankChurnersEval.csv')
X_pre = orig_data.iloc[:,2:-1]
X = pd.get_dummies(X_pre, drop_first=True)
y = np.where(orig_data['Attrition_Flag'] == 'Existing Customer', 0, 1).astype(bool)
orig_data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  818903583  Existing Customer            44      M                5
# 1  715150983  Attrited Customer            44      F                3
# 2  789180933  Existing Customer            37      F                3
# 3  717667833  Existing Customer            34      M                1
# 4  714745608  Existing Customer            51      F                4
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0      Uneducated       Divorced     $60K - $80K          Blue
# 1         Unknown         Single         Unknown          Blue
# 2     High School         Single  Less than $40K          Blue
# 3        Graduate        Married     $40K - $60K          Blue
# 4     High School         Single  Less than $40K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       2                      0
# 1              34  ...                       3                      3
# 2              26  ...                       1                      2
# 3              36  ...                       2                      3
# 4              33  ...                       4                      3
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       16034.0                 1597          14437.0                 0.775
# 1       26021.0                    0          26021.0                 1.040
# 2        2917.0                 2216            701.0                 0.810
# 3        3735.0                 1285           2450.0                 1.034
# 4        3068.0                 2071            997.0                 0.854
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             3628              59                0.903                  0.100
# 1             8898              60                0.538                  0.000
# 2             4524              67                0.489                  0.760
# 3             1877              33                1.200                  0.344
# 4             5524              71                0.972                  0.675
#
# [5 rows x 21 columns]

# %%
#create additional ratio features
X['avg_transaction_amt'] = X['Total_Trans_Amt']/X['Total_Trans_Ct']
X['avg_trans_pct_of_lmt'] = X['avg_transaction_amt']/X['Credit_Limit']

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# define pipeline
over = SMOTE(random_state=0)
under = RandomUnderSampler(random_state=0)
decision_tree = DecisionTreeClassifier(random_state=0)
steps = [('over', over), 
         ('under', under),
         ('classifier', decision_tree)]
model_w_feats = Pipeline(steps=steps)

# %%
#goal is to minimize false negatives (do not want to miss a customer that will churn)
#use recall as primary metric to minimize false negatives
cv_scores = cross_val_score(model_w_feats, X_train, y_train, cv=5, scoring='recall')
cv_scores
# Out:
# array([0.83125   , 0.825     , 0.85534591, 0.8125    , 0.825     ])

# %%
# Make predictions and compute probabilities
model_w_feats.fit(X_train, y_train)
y_pred = model_w_feats.predict(X_test)
y_pred_prob = model_w_feats.predict_proba(X_test)[:, 1]  # Get probabilities for the positive class

# %%
# Print classification report
print('Baseline model with additional features test results')
print(classification_report(y_test, y_pred, target_names=['Existing Customer', 'Attrited Customer']))
# Out:
# Baseline model with additional features test results
#                    precision    recall  f1-score   support
#
# Existing Customer       0.96      0.95      0.96      1787
# Attrited Customer       0.76      0.79      0.78       340
#
#          accuracy                           0.93      2127
#         macro avg       0.86      0.87      0.87      2127
#      weighted avg       0.93      0.93      0.93      2127

# %%
#confusion matrix
cm = confusion_matrix_class(confusion_matrix(y_test, y_pred), inverse=True)
cm.cm
# Out:
# array([[ 269,   71],
#        [  85, 1702]], dtype=int64)

# %%
# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot the lift curves
plot_lift_curves(y_test, y_pred_prob)

# %%
# Get feature importances
classifier = model_w_feats.named_steps['classifier']
feature_importances = classifier.feature_importances_

# Create a DataFrame for better visualization
feature_importances_df = pd.DataFrame({
    'feature': X.columns,
    'importance': feature_importances
}).sort_values(by='importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances_df['feature'], feature_importances_df['importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances from Decision Tree Classifier')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature on top
plt.show()

# %%
feature_importances_df
# Out:
#                            feature  importance
# 11                  Total_Trans_Ct    0.453526
# 31             avg_transaction_amt    0.114841
# 10                 Total_Trans_Amt    0.102319
# 7              Total_Revolving_Bal    0.086594
# 3         Total_Relationship_Count    0.064565
# 9             Total_Amt_Chng_Q4_Q1    0.051095
# 12             Total_Ct_Chng_Q4_Q1    0.042639
# 0                     Customer_Age    0.022030
# 32            avg_trans_pct_of_lmt    0.012652
# 8                  Avg_Open_To_Buy    0.012376
# 2                   Months_on_book    0.007535
# 1                  Dependent_count    0.005602
# 5            Contacts_Count_12_mon    0.004411
# 6                     Credit_Limit    0.003974
# 4           Months_Inactive_12_mon    0.002669
# 21           Marital_Status_Single    0.002347
# 15        Education_Level_Graduate    0.001453
# 13                        Gender_M    0.001247
# 16     Education_Level_High School    0.001153
# 18      Education_Level_Uneducated    0.000961
# 28              Card_Category_Gold    0.000881
# 22          Marital_Status_Unknown    0.000871
# 25    Income_Category_$80K - $120K    0.000796
# 24     Income_Category_$60K - $80K    0.000769
# 26  Income_Category_Less than $40K    0.000705
# 19         Education_Level_Unknown    0.000692
# 17   Education_Level_Post-Graduate    0.000420
# 27         Income_Category_Unknown    0.000400
# 23     Income_Category_$40K - $60K    0.000384
# 20          Marital_Status_Married    0.000092
# 14       Education_Level_Doctorate    0.000000
# 29          Card_Category_Platinum    0.000000
# 30            Card_Category_Silver    0.000000
