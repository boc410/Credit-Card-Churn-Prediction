# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix, recall_score, make_scorer

# %run functions.ipynb

# %%
#import data
orig_data = pd.read_csv('../Data/BankChurnersEval.csv')
X_pre = orig_data.iloc[:,2:-1]
X = pd.get_dummies(X_pre, drop_first=True)
y = np.where(orig_data['Attrition_Flag'] == 'Existing Customer', 0, 1).astype(bool)
orig_data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  818903583  Existing Customer            44      M                5
# 1  715150983  Attrited Customer            44      F                3
# 2  789180933  Existing Customer            37      F                3
# 3  717667833  Existing Customer            34      M                1
# 4  714745608  Existing Customer            51      F                4
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0      Uneducated       Divorced     $60K - $80K          Blue
# 1         Unknown         Single         Unknown          Blue
# 2     High School         Single  Less than $40K          Blue
# 3        Graduate        Married     $40K - $60K          Blue
# 4     High School         Single  Less than $40K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       2                      0
# 1              34  ...                       3                      3
# 2              26  ...                       1                      2
# 3              36  ...                       2                      3
# 4              33  ...                       4                      3
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       16034.0                 1597          14437.0                 0.775
# 1       26021.0                    0          26021.0                 1.040
# 2        2917.0                 2216            701.0                 0.810
# 3        3735.0                 1285           2450.0                 1.034
# 4        3068.0                 2071            997.0                 0.854
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             3628              59                0.903                  0.100
# 1             8898              60                0.538                  0.000
# 2             4524              67                0.489                  0.760
# 3             1877              33                1.200                  0.344
# 4             5524              71                0.972                  0.675
#
# [5 rows x 21 columns]

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Define pipeline
over = SMOTE(random_state=0)
under = RandomUnderSampler(random_state=0)
rf = RandomForestClassifier(random_state=0)
steps = [('over', over), 
         ('under', under),
         ('classifier', rf)]
model = Pipeline(steps=steps)

# %%
# Define parameter grid
param_grid = {
    'classifier__n_estimators': [50, 100, 200],
    'classifier__max_depth': [30, 50],
    'classifier__min_samples_split': [2, 4],
    'classifier__min_samples_leaf': [2],
    'classifier__max_features': ['sqrt', 'log2']}

# %%
# Define recall as the scoring metric
recall_scorer = make_scorer(recall_score, average='binary')

# %%
print("Random forest test results")
# Out:
# Random forest test results

# %%
# Perform the grid search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring=recall_scorer, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('over', SMOTE(random_state=0)),
#                                        ('under',
#                                         RandomUnderSampler(random_state=0)),
#                                        ('classifier',
#                                         RandomForestClassifier(random_state=0))]),
#              n_jobs=-1,
#              param_grid={'classifier__max_depth': [30, 50],
#                          'classifier__max_features': ['sqrt', 'log2'],
#                          'classifier__min_samples_leaf': [2],
#                          'classifier__min_samples_split': [2, 4],
#                          'classifier__n_estimators': [50, 100, 200]},
#              scoring=make_scorer(recall_score, average=binary), verbose=2)

# %%
# Access the cv_results_ attribute
results = grid_search.cv_results_

# Convert the results to a DataFrame for better readability
results_df = pd.DataFrame(results)

# Display the DataFrame
results_df.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2        3.388573      0.136794         0.079424        0.020876
# 5        3.470582      0.146977         0.069224        0.006685
# 17       3.526859      0.221258         0.069933        0.008188
# 14       3.337646      0.160531         0.071024        0.016197
# 1        1.905218      0.085512         0.039522        0.006386
# 4        1.809428      0.077968         0.037606        0.002869
# 16       1.848330      0.166806         0.041421        0.008081
# 13       1.646160      0.017547         0.034811        0.003588
# 11       2.873514      0.071113         0.069823        0.006427
# 20       3.138254      0.151738         0.074593        0.008803
# 23       2.692207      0.129081         0.046610        0.008181
# 8        2.891666      0.110342         0.065623        0.004915
# 12       0.863244      0.024794         0.018308        0.002046
# 15       0.971751      0.099222         0.026008        0.005551
# 3        0.919575      0.050865         0.020605        0.001357
# 0        1.035188      0.018014         0.024508        0.003920
# 22       1.694877      0.179943         0.042615        0.006687
# 7        1.592319      0.058704         0.035305        0.001940
# 19       1.683156      0.075366         0.037318        0.003117
# 10       1.584252      0.045973         0.039111        0.007597
# 9        0.814053      0.040318         0.019002        0.002092
# 6        0.891593      0.061370         0.031905        0.012136
# 18       0.821294      0.077710         0.021116        0.002082
# 21       0.864762      0.090885         0.024706        0.004036
#
#    param_classifier__max_depth param_classifier__max_features  \
# 2                           30                           sqrt
# 5                           30                           sqrt
# 17                          50                           sqrt
# 14                          50                           sqrt
# 1                           30                           sqrt
# 4                           30                           sqrt
# 16                          50                           sqrt
# 13                          50                           sqrt
# 11                          30                           log2
# 20                          50                           log2
# 23                          50                           log2
# 8                           30                           log2
# 12                          50                           sqrt
# 15                          50                           sqrt
# 3                           30                           sqrt
# 0                           30                           sqrt
# 22                          50                           log2
# 7                           30                           log2
# 19                          50                           log2
# 10                          30                           log2
# 9                           30                           log2
# 6                           30                           log2
# 18                          50                           log2
# 21                          50                           log2
#
#    param_classifier__min_samples_leaf param_classifier__min_samples_split  \
# 2                                   2                                   2
# 5                                   2                                   4
# 17                                  2                                   4
# 14                                  2                                   2
# 1                                   2                                   2
# 4                                   2                                   4
# 16                                  2                                   4
# 13                                  2                                   2
# 11                                  2                                   4
# 20                                  2                                   2
# 23                                  2                                   4
# 8                                   2                                   2
# 12                                  2                                   2
# 15                                  2                                   4
# 3                                   2                                   4
# 0                                   2                                   2
# 22                                  2                                   4
# 7                                   2                                   2
# 19                                  2                                   2
# 10                                  2                                   4
# 9                                   2                                   4
# 6                                   2                                   2
# 18                                  2                                   2
# 21                                  2                                   4
#
#    param_classifier__n_estimators  \
# 2                             200
# 5                             200
# 17                            200
# 14                            200
# 1                             100
# 4                             100
# 16                            100
# 13                            100
# 11                            200
# 20                            200
# 23                            200
# 8                             200
# 12                             50
# 15                             50
# 3                              50
# 0                              50
# 22                            100
# 7                             100
# 19                            100
# 10                            100
# 9                              50
# 6                              50
# 18                             50
# 21                             50
#
#                                                params  split0_test_score  \
# 2   {'classifier__max_depth': 30, 'classifier__max...            0.84375
# 5   {'classifier__max_depth': 30, 'classifier__max...            0.84375
# 17  {'classifier__max_depth': 50, 'classifier__max...            0.84375
# 14  {'classifier__max_depth': 50, 'classifier__max...            0.84375
# 1   {'classifier__max_depth': 30, 'classifier__max...            0.83750
# 4   {'classifier__max_depth': 30, 'classifier__max...            0.83750
# 16  {'classifier__max_depth': 50, 'classifier__max...            0.83750
# 13  {'classifier__max_depth': 50, 'classifier__max...            0.83750
# 11  {'classifier__max_depth': 30, 'classifier__max...            0.84375
# 20  {'classifier__max_depth': 50, 'classifier__max...            0.84375
# 23  {'classifier__max_depth': 50, 'classifier__max...            0.84375
# 8   {'classifier__max_depth': 30, 'classifier__max...            0.84375
# 12  {'classifier__max_depth': 50, 'classifier__max...            0.82500
# 15  {'classifier__max_depth': 50, 'classifier__max...            0.82500
# 3   {'classifier__max_depth': 30, 'classifier__max...            0.82500
# 0   {'classifier__max_depth': 30, 'classifier__max...            0.82500
# 22  {'classifier__max_depth': 50, 'classifier__max...            0.83750
# 7   {'classifier__max_depth': 30, 'classifier__max...            0.83750
# 19  {'classifier__max_depth': 50, 'classifier__max...            0.83750
# 10  {'classifier__max_depth': 30, 'classifier__max...            0.83750
# 9   {'classifier__max_depth': 30, 'classifier__max...            0.83125
# 6   {'classifier__max_depth': 30, 'classifier__max...            0.83125
# 18  {'classifier__max_depth': 50, 'classifier__max...            0.83125
# 21  {'classifier__max_depth': 50, 'classifier__max...            0.83125
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 2             0.83125           0.849057            0.88125
# 5             0.83125           0.849057            0.88125
# 17            0.83125           0.849057            0.88125
# 14            0.83125           0.849057            0.88125
# 1             0.81875           0.861635            0.88125
# 4             0.81875           0.861635            0.88125
# 16            0.81875           0.861635            0.88125
# 13            0.81875           0.861635            0.88125
# 11            0.83125           0.849057            0.85625
# 20            0.83125           0.849057            0.85625
# 23            0.83125           0.849057            0.85625
# 8             0.83125           0.849057            0.85625
# 12            0.81875           0.830189            0.86875
# 15            0.81875           0.830189            0.86875
# 3             0.81875           0.830189            0.86875
# 0             0.81875           0.830189            0.86875
# 22            0.81875           0.849057            0.85625
# 7             0.81875           0.849057            0.85625
# 19            0.81875           0.849057            0.85625
# 10            0.81875           0.849057            0.85625
# 9             0.82500           0.830189            0.83750
# 6             0.82500           0.830189            0.83750
# 18            0.82500           0.830189            0.83750
# 21            0.82500           0.830189            0.83750
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 2             0.86875         0.854811        0.017910                1
# 5             0.86875         0.854811        0.017910                1
# 17            0.86875         0.854811        0.017910                1
# 14            0.86875         0.854811        0.017910                1
# 1             0.85625         0.851077        0.021345                5
# 4             0.85625         0.851077        0.021345                5
# 16            0.85625         0.851077        0.021345                5
# 13            0.85625         0.851077        0.021345                5
# 11            0.81250         0.838561        0.015379                9
# 20            0.81250         0.838561        0.015379                9
# 23            0.81250         0.838561        0.015379                9
# 8             0.81250         0.838561        0.015379                9
# 12            0.84375         0.837288        0.017758               13
# 15            0.84375         0.837288        0.017758               13
# 3             0.84375         0.837288        0.017758               13
# 0             0.84375         0.837288        0.017758               13
# 22            0.81875         0.836061        0.015349               17
# 7             0.81875         0.836061        0.015349               17
# 19            0.81875         0.836061        0.015349               17
# 10            0.81875         0.836061        0.015349               17
# 9             0.79375         0.823538        0.015415               21
# 6             0.79375         0.823538        0.015415               21
# 18            0.79375         0.823538        0.015415               21
# 21            0.79375         0.823538        0.015415               21

# %%
# Check the best parameters
print("Best parameters found: ")
print(pd.Series(grid_search.best_params_))
# Out:
# Best parameters found:
# classifier__max_depth              30
# classifier__max_features         sqrt
# classifier__min_samples_leaf        2
# classifier__min_samples_split       2
# classifier__n_estimators          200
# dtype: object

# %%
# Evaluate the model with the best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
y_pred_prob = best_model.predict_proba(X_test)[:, 1]  # Get probabilities for the positive class

# %%
# Print classification report
print(classification_report(y_test, y_pred, target_names=['Existing Customer', 'Attrited Customer']))
# Out:
#                    precision    recall  f1-score   support
#
# Existing Customer       0.97      0.97      0.97      1787
# Attrited Customer       0.86      0.84      0.85       340
#
#          accuracy                           0.95      2127
#         macro avg       0.91      0.91      0.91      2127
#      weighted avg       0.95      0.95      0.95      2127

# %%
results = pd.DataFrame(zip(y_test, y_pred_prob), columns=['actual','confidence'])
results_df = pd.DataFrame()

for prob in range(0,65,5):
    col_name = "threshold_" + str(prob)
    results[prob] = results['confidence'] > (prob/100)
    cm = confusion_matrix_class(confusion_matrix(results['actual'], results[prob]),inverse=True)
    #add record to test results df
    new_record = create_results_record(label=col_name,  
                                       cm=cm)
    results_df = pd.concat([results_df, pd.DataFrame([new_record])], ignore_index=True).drop_duplicates()
    
print(results_df.to_string())
# Out:
#            label  accuracy  precision  recall     F1   tp    fp  fn    tn  pred_pos  pred_neg  act_pos  act_neg  total
# 0    threshold_0     0.186      0.164   1.000  0.282  340  1731   0    56      2071        56      340     1787   2127
# 1    threshold_5     0.599      0.285   0.997  0.443  339   852   1   935      1191       936      340     1787   2127
# 2   threshold_10     0.753      0.392   0.994  0.562  338   524   2  1263       862      1265      340     1787   2127
# 3   threshold_15     0.834      0.490   0.994  0.656  338   352   2  1435       690      1437      340     1787   2127
# 4   threshold_20     0.879      0.571   0.982  0.722  334   251   6  1536       585      1542      340     1787   2127
# 5   threshold_25     0.906      0.633   0.971  0.767  330   191  10  1596       521      1606      340     1787   2127
# 6   threshold_30     0.924      0.695   0.938  0.798  319   140  21  1647       459      1668      340     1787   2127
# 7   threshold_35     0.937      0.748   0.915  0.823  311   105  29  1682       416      1711      340     1787   2127
# 8   threshold_40     0.945      0.792   0.885  0.836  301    79  39  1708       380      1747      340     1787   2127
# 9   threshold_45     0.947      0.815   0.868  0.840  295    67  45  1720       362      1765      340     1787   2127
# 10  threshold_50     0.952      0.856   0.838  0.847  285    48  55  1739       333      1794      340     1787   2127
# 11  threshold_55     0.951      0.893   0.788  0.837  268    32  72  1755       300      1827      340     1787   2127
# 12  threshold_60     0.945      0.924   0.712  0.804  242    20  98  1767       262      1865      340     1787   2127

# %%
# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot the lift curves
plot_lift_curves(y_test, y_pred_prob)

# %%
# Get feature importances
classifier = best_model.named_steps['classifier']
feature_importances = classifier.feature_importances_

# Create a DataFrame for better visualization
feature_importances_df = pd.DataFrame({
    'feature': X.columns,
    'importance': feature_importances
}).sort_values(by='importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances_df['feature'], feature_importances_df['importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances from Random Forest Classifier')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature on top
plt.show()

# %%
feature_importances_df
# Out:
#                            feature  importance
# 11                  Total_Trans_Ct    0.214926
# 10                 Total_Trans_Amt    0.200257
# 7              Total_Revolving_Bal    0.118713
# 12             Total_Ct_Chng_Q4_Q1    0.092784
# 3         Total_Relationship_Count    0.059834
# 9             Total_Amt_Chng_Q4_Q1    0.045958
# 6                     Credit_Limit    0.030882
# 8                  Avg_Open_To_Buy    0.029976
# 0                     Customer_Age    0.027153
# 21           Marital_Status_Single    0.025063
# 4           Months_Inactive_12_mon    0.019525
# 2                   Months_on_book    0.018487
# 20          Marital_Status_Married    0.014694
# 26  Income_Category_Less than $40K    0.014168
# 5            Contacts_Count_12_mon    0.013248
# 15        Education_Level_Graduate    0.011075
# 1                  Dependent_count    0.010090
# 13                        Gender_M    0.007915
# 19         Education_Level_Unknown    0.007168
# 27         Income_Category_Unknown    0.006266
# 18      Education_Level_Uneducated    0.004944
# 25    Income_Category_$80K - $120K    0.004375
# 16     Education_Level_High School    0.004013
# 23     Income_Category_$40K - $60K    0.003308
# 22          Marital_Status_Unknown    0.003223
# 30            Card_Category_Silver    0.002704
# 14       Education_Level_Doctorate    0.002546
# 24     Income_Category_$60K - $80K    0.002355
# 28              Card_Category_Gold    0.002256
# 17   Education_Level_Post-Graduate    0.001448
# 29          Card_Category_Platinum    0.000644
