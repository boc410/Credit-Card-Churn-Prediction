# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix, recall_score, make_scorer

# %run functions.ipynb

# %%
#import data
orig_data = pd.read_csv('../Data/BankChurners.csv')
orig_data.drop(columns=orig_data.columns[-2:], inplace=True)
X_pre = orig_data.iloc[:,2:-1]
X = pd.get_dummies(X_pre, drop_first=True)
y = np.where(orig_data['Attrition_Flag'] == 'Existing Customer', 0, 1).astype(bool)
orig_data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Define pipeline
over = SMOTE(random_state=0)
under = RandomUnderSampler(random_state=0)
rf = RandomForestClassifier(random_state=0)
steps = [('over', over), 
         ('under', under),
         ('classifier', rf)]
model = Pipeline(steps=steps)

# %%
# Define parameter grid
param_grid = {
    'classifier__n_estimators': [50, 100, 200],
    'classifier__max_depth': [30, 50],
    'classifier__min_samples_split': [2, 4],
    'classifier__min_samples_leaf': [2],
    'classifier__max_features': ['sqrt', 'log2']}

# %%
# Define recall as the scoring metric
recall_scorer = make_scorer(recall_score, average='binary')

# %%
print("Random forest test results")
# Out:
# Random forest test results

# %%
# Perform the grid search
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring=recall_scorer, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('over', SMOTE(random_state=0)),
#                                        ('under',
#                                         RandomUnderSampler(random_state=0)),
#                                        ('classifier',
#                                         RandomForestClassifier(random_state=0))]),
#              n_jobs=-1,
#              param_grid={'classifier__max_depth': [30, 50],
#                          'classifier__max_features': ['sqrt', 'log2'],
#                          'classifier__min_samples_leaf': [2],
#                          'classifier__min_samples_split': [2, 4],
#                          'classifier__n_estimators': [50, 100, 200]},
#              scoring=make_scorer(recall_score, average=binary), verbose=2)

# %%
# Access the cv_results_ attribute
results = grid_search.cv_results_

# Convert the results to a DataFrame for better readability
results_df = pd.DataFrame(results)

# Display the DataFrame
results_df.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1        2.579304      0.181660         0.055237        0.010543
# 4        2.467673      0.080838         0.044615        0.004028
# 16       2.805553      0.077988         0.066773        0.012841
# 13       2.687436      0.056986         0.058924        0.012787
# 2        4.931100      0.165323         0.089733        0.004873
# 5        4.684824      0.010260         0.087628        0.004430
# 17       6.084918      0.257371         0.111544        0.023201
# 14       5.370161      0.082548         0.103401        0.021178
# 0        1.322740      0.065603         0.028921        0.005393
# 3        1.405371      0.057245         0.026710        0.004015
# 15       1.416395      0.024880         0.030415        0.003648
# 12       1.311168      0.024305         0.025816        0.003503
# 20       4.782497      0.181285         0.087421        0.007190
# 11       4.341955      0.115519         0.093141        0.006913
# 8        4.116735      0.049162         0.103906        0.003504
# 23       3.723269      0.295641         0.072092        0.010209
# 10       2.181495      0.056456         0.050920        0.003762
# 7        2.044932      0.029666         0.045612        0.005427
# 19       2.781568      0.192403         0.053413        0.004695
# 22       2.407866      0.081500         0.055622        0.007835
# 9        1.056937      0.035538         0.026016        0.003614
# 18       1.476990      0.111044         0.036604        0.007813
# 6        1.105628      0.047085         0.033408        0.010031
# 21       1.342916      0.093484         0.028406        0.002426
#
#    param_classifier__max_depth param_classifier__max_features  \
# 1                           30                           sqrt
# 4                           30                           sqrt
# 16                          50                           sqrt
# 13                          50                           sqrt
# 2                           30                           sqrt
# 5                           30                           sqrt
# 17                          50                           sqrt
# 14                          50                           sqrt
# 0                           30                           sqrt
# 3                           30                           sqrt
# 15                          50                           sqrt
# 12                          50                           sqrt
# 20                          50                           log2
# 11                          30                           log2
# 8                           30                           log2
# 23                          50                           log2
# 10                          30                           log2
# 7                           30                           log2
# 19                          50                           log2
# 22                          50                           log2
# 9                           30                           log2
# 18                          50                           log2
# 6                           30                           log2
# 21                          50                           log2
#
#    param_classifier__min_samples_leaf param_classifier__min_samples_split  \
# 1                                   2                                   2
# 4                                   2                                   4
# 16                                  2                                   4
# 13                                  2                                   2
# 2                                   2                                   2
# 5                                   2                                   4
# 17                                  2                                   4
# 14                                  2                                   2
# 0                                   2                                   2
# 3                                   2                                   4
# 15                                  2                                   4
# 12                                  2                                   2
# 20                                  2                                   2
# 11                                  2                                   4
# 8                                   2                                   2
# 23                                  2                                   4
# 10                                  2                                   4
# 7                                   2                                   2
# 19                                  2                                   2
# 22                                  2                                   4
# 9                                   2                                   4
# 18                                  2                                   2
# 6                                   2                                   2
# 21                                  2                                   4
#
#    param_classifier__n_estimators  \
# 1                             100
# 4                             100
# 16                            100
# 13                            100
# 2                             200
# 5                             200
# 17                            200
# 14                            200
# 0                              50
# 3                              50
# 15                             50
# 12                             50
# 20                            200
# 11                            200
# 8                             200
# 23                            200
# 10                            100
# 7                             100
# 19                            100
# 22                            100
# 9                              50
# 18                             50
# 6                              50
# 21                             50
#
#                                                params  split0_test_score  \
# 1   {'classifier__max_depth': 30, 'classifier__max...           0.854701
# 4   {'classifier__max_depth': 30, 'classifier__max...           0.854701
# 16  {'classifier__max_depth': 50, 'classifier__max...           0.854701
# 13  {'classifier__max_depth': 50, 'classifier__max...           0.854701
# 2   {'classifier__max_depth': 30, 'classifier__max...           0.863248
# 5   {'classifier__max_depth': 30, 'classifier__max...           0.863248
# 17  {'classifier__max_depth': 50, 'classifier__max...           0.863248
# 14  {'classifier__max_depth': 50, 'classifier__max...           0.863248
# 0   {'classifier__max_depth': 30, 'classifier__max...           0.837607
# 3   {'classifier__max_depth': 30, 'classifier__max...           0.837607
# 15  {'classifier__max_depth': 50, 'classifier__max...           0.837607
# 12  {'classifier__max_depth': 50, 'classifier__max...           0.837607
# 20  {'classifier__max_depth': 50, 'classifier__max...           0.824786
# 11  {'classifier__max_depth': 30, 'classifier__max...           0.824786
# 8   {'classifier__max_depth': 30, 'classifier__max...           0.824786
# 23  {'classifier__max_depth': 50, 'classifier__max...           0.824786
# 10  {'classifier__max_depth': 30, 'classifier__max...           0.816239
# 7   {'classifier__max_depth': 30, 'classifier__max...           0.816239
# 19  {'classifier__max_depth': 50, 'classifier__max...           0.816239
# 22  {'classifier__max_depth': 50, 'classifier__max...           0.816239
# 9   {'classifier__max_depth': 30, 'classifier__max...           0.790598
# 18  {'classifier__max_depth': 50, 'classifier__max...           0.790598
# 6   {'classifier__max_depth': 30, 'classifier__max...           0.790598
# 21  {'classifier__max_depth': 50, 'classifier__max...           0.790598
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 1            0.914530           0.872340           0.876068
# 4            0.914530           0.872340           0.876068
# 16           0.914530           0.872340           0.876068
# 13           0.914530           0.872340           0.876068
# 2            0.910256           0.889362           0.858974
# 5            0.910256           0.889362           0.858974
# 17           0.910256           0.889362           0.858974
# 14           0.910256           0.889362           0.858974
# 0            0.893162           0.889362           0.867521
# 3            0.893162           0.889362           0.867521
# 15           0.893162           0.889362           0.867521
# 12           0.893162           0.889362           0.867521
# 20           0.901709           0.872340           0.850427
# 11           0.901709           0.872340           0.850427
# 8            0.901709           0.872340           0.850427
# 23           0.901709           0.872340           0.850427
# 10           0.897436           0.859574           0.833333
# 7            0.897436           0.859574           0.833333
# 19           0.897436           0.859574           0.833333
# 22           0.897436           0.859574           0.833333
# 9            0.901709           0.876596           0.833333
# 18           0.901709           0.876596           0.833333
# 6            0.901709           0.876596           0.833333
# 21           0.901709           0.876596           0.833333
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 1            0.850427         0.873613        0.022703                1
# 4            0.850427         0.873613        0.022703                1
# 16           0.850427         0.873613        0.022703                1
# 13           0.850427         0.873613        0.022703                1
# 2            0.846154         0.873599        0.023093                5
# 5            0.846154         0.873599        0.023093                5
# 17           0.846154         0.873599        0.023093                5
# 14           0.846154         0.873599        0.023093                5
# 0            0.837607         0.865052        0.024057                9
# 3            0.837607         0.865052        0.024057                9
# 15           0.837607         0.865052        0.024057                9
# 12           0.837607         0.865052        0.024057                9
# 20           0.846154         0.859083        0.026119               13
# 11           0.846154         0.859083        0.026119               13
# 8            0.846154         0.859083        0.026119               13
# 23           0.846154         0.859083        0.026119               13
# 10           0.837607         0.848838        0.027951               17
# 7            0.837607         0.848838        0.027951               17
# 19           0.837607         0.848838        0.027951               17
# 22           0.837607         0.848838        0.027951               17
# 9            0.829060         0.846259        0.038874               21
# 18           0.829060         0.846259        0.038874               21
# 6            0.829060         0.846259        0.038874               21
# 21           0.829060         0.846259        0.038874               21

# %%
# Check the best parameters
print("Best parameters found: ")
print(pd.Series(grid_search.best_params_))
# Out:
# Best parameters found:
# classifier__max_depth              30
# classifier__max_features         sqrt
# classifier__min_samples_leaf        2
# classifier__min_samples_split       2
# classifier__n_estimators          100
# dtype: object

# %%
# Evaluate the model with the best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
y_pred_prob = best_model.predict_proba(X_test)[:, 1]  # Get probabilities for the positive class

# %%
# Print classification report
print(classification_report(y_test, y_pred, target_names=['Existing Customer', 'Attrited Customer']))
# Out:
#                    precision    recall  f1-score   support
#
# Existing Customer       0.97      0.97      0.97      2583
# Attrited Customer       0.83      0.86      0.84       456
#
#          accuracy                           0.95      3039
#         macro avg       0.90      0.91      0.91      3039
#      weighted avg       0.95      0.95      0.95      3039

# %%
results = pd.DataFrame(zip(y_test, y_pred_prob), columns=['actual','confidence'])
results_df = pd.DataFrame()

for prob in range(0,65,5):
    col_name = "threshold_" + str(prob)
    results[prob] = results['confidence'] > (prob/100)
    cm = confusion_matrix_class(confusion_matrix(results['actual'], results[prob]),inverse=True)
    #add record to test results df
    new_record = create_results_record(label=col_name,  
                                       cm=cm)
    results_df = pd.concat([results_df, pd.DataFrame([new_record])], ignore_index=True).drop_duplicates()
    
print(results_df.to_string())
# Out:
#            label  accuracy  precision  recall     F1   tp    fp   fn    tn  pred_pos  pred_neg  act_pos  act_neg  total
# 0    threshold_0     0.216      0.161   1.000  0.277  456  2383    0   200      2839       200      456     2583   3039
# 1    threshold_5     0.582      0.264   1.000  0.418  456  1270    0  1313      1726      1313      456     2583   3039
# 2   threshold_10     0.734      0.361   1.000  0.530  456   808    0  1775      1264      1775      456     2583   3039
# 3   threshold_15     0.815      0.448   0.998  0.619  455   560    1  2023      1015      2024      456     2583   3039
# 4   threshold_20     0.864      0.525   0.991  0.686  452   409    4  2174       861      2178      456     2583   3039
# 5   threshold_25     0.902      0.608   0.982  0.751  448   289    8  2294       737      2302      456     2583   3039
# 6   threshold_30     0.924      0.671   0.967  0.792  441   216   15  2367       657      2382      456     2583   3039
# 7   threshold_35     0.936      0.717   0.950  0.817  433   171   23  2412       604      2435      456     2583   3039
# 8   threshold_40     0.945      0.756   0.932  0.835  425   137   31  2446       562      2477      456     2583   3039
# 9   threshold_45     0.949      0.794   0.888  0.839  405   105   51  2478       510      2529      456     2583   3039
# 10  threshold_50     0.951      0.826   0.855  0.841  390    82   66  2501       472      2567      456     2583   3039
# 11  threshold_55     0.953      0.865   0.816  0.840  372    58   84  2525       430      2609      456     2583   3039
# 12  threshold_60     0.951      0.899   0.759  0.823  346    39  110  2544       385      2654      456     2583   3039

# %%
# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot the lift curves
plot_lift_curves(y_test, y_pred_prob)

# %%
# Get feature importances
classifier = best_model.named_steps['classifier']
feature_importances = classifier.feature_importances_

# Create a DataFrame for better visualization
feature_importances_df = pd.DataFrame({
    'feature': X.columns,
    'importance': feature_importances
}).sort_values(by='importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances_df['feature'], feature_importances_df['importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances from Random Forest Classifier')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature on top
plt.show()

# %%
feature_importances_df
# Out:
#                            feature  importance
# 11                  Total_Trans_Ct    0.200054
# 10                 Total_Trans_Amt    0.186503
# 7              Total_Revolving_Bal    0.133689
# 12             Total_Ct_Chng_Q4_Q1    0.090965
# 3         Total_Relationship_Count    0.062354
# 9             Total_Amt_Chng_Q4_Q1    0.056032
# 8                  Avg_Open_To_Buy    0.029607
# 6                     Credit_Limit    0.029461
# 21           Marital_Status_Single    0.027476
# 0                     Customer_Age    0.024586
# 4           Months_Inactive_12_mon    0.023517
# 20          Marital_Status_Married    0.017184
# 2                   Months_on_book    0.016871
# 5            Contacts_Count_12_mon    0.014379
# 26  Income_Category_Less than $40K    0.012586
# 13                        Gender_M    0.011156
# 1                  Dependent_count    0.009264
# 15        Education_Level_Graduate    0.007712
# 19         Education_Level_Unknown    0.007659
# 25    Income_Category_$80K - $120K    0.005892
# 23     Income_Category_$40K - $60K    0.005262
# 16     Education_Level_High School    0.004502
# 27         Income_Category_Unknown    0.004151
# 18      Education_Level_Uneducated    0.003822
# 22          Marital_Status_Unknown    0.003546
# 17   Education_Level_Post-Graduate    0.003244
# 24     Income_Category_$60K - $80K    0.002849
# 30            Card_Category_Silver    0.002482
# 14       Education_Level_Doctorate    0.002237
# 28              Card_Category_Gold    0.000683
# 29          Card_Category_Platinum    0.000275
