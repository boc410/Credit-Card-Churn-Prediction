# %%
# %run baseline_model.ipynb
# Out:
# Baseline model test results
#                    precision    recall  f1-score   support
#
# Existing Customer       0.96      0.95      0.95      1787
# Attrited Customer       0.74      0.78      0.76       340
#
#          accuracy                           0.92      2127
#         macro avg       0.85      0.87      0.86      2127
#      weighted avg       0.92      0.92      0.92      2127

# %%
# %run baseline_model_w_additional_features.ipynb
# Out:
# Baseline model with additional features test results
#                    precision    recall  f1-score   support
#
# Existing Customer       0.96      0.95      0.96      1787
# Attrited Customer       0.76      0.79      0.78       340
#
#          accuracy                           0.93      2127
#         macro avg       0.86      0.87      0.87      2127
#      weighted avg       0.93      0.93      0.93      2127

# %%
#additional features decreased recall and ROC curve area slightly

# %%
# %run tuned_decision_tree_model.ipynb
# Out:
# Tuned Decision Tree test results
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best parameters found:
# classifier__criterion            gini
# classifier__max_depth              10
# classifier__max_features         None
# classifier__min_samples_leaf        1
# classifier__min_samples_split       2
# dtype: object
#                    precision    recall  f1-score   support
#
# Existing Customer       0.96      0.94      0.95      1787
# Attrited Customer       0.72      0.81      0.77       340
#
#          accuracy                           0.92      2127
#         macro avg       0.84      0.88      0.86      2127
#      weighted avg       0.93      0.92      0.92      2127
#
#            label  accuracy  precision  recall     F1   tp   fp  fn    tn  pred_pos  pred_neg  act_pos  act_neg  total
# 0    threshold_0     0.798      0.434   0.868  0.578  295  385  45  1402       680      1447      340     1787   2127
# ...

# %%
#hyped tuned model matched recall and increased ROC curve area

# %%
# %run random_forest_model.ipynb
# Out:
# Random forest test results
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best parameters found:
# classifier__max_depth              30
# classifier__max_features         sqrt
# classifier__min_samples_leaf        2
# classifier__min_samples_split       2
# classifier__n_estimators          200
# dtype: object
#                    precision    recall  f1-score   support
#
# Existing Customer       0.97      0.97      0.97      1787
# Attrited Customer       0.86      0.84      0.85       340
#
#          accuracy                           0.95      2127
#         macro avg       0.91      0.91      0.91      2127
#      weighted avg       0.95      0.95      0.95      2127
#
#            label  accuracy  precision  recall     F1   tp    fp  fn    tn  pred_pos  pred_neg  act_pos  act_neg  total
# 0    threshold_0     0.186      0.164   1.000  0.282  340  1731   0    56      2071        56      340     1787   2127
# ...

# %%
#random forest is much more effective (ROC area increase and recall increase)

# %%
# %run catboost_model.ipynb
# Out:
# catboost test results
# 0:	learn: 0.5758228	total: 210ms	remaining: 3m 29s
# 200:	learn: 0.0263458	total: 17.5s	remaining: 1m 9s
# 400:	learn: 0.0096950	total: 33.8s	remaining: 50.6s
# 600:	learn: 0.0054054	total: 52.6s	remaining: 34.9s
# 800:	learn: 0.0037370	total: 1m 10s	remaining: 17.5s
# 999:	learn: 0.0029164	total: 1m 27s	remaining: 0us
#                    precision    recall  f1-score   support
#
# Existing Customer       0.97      0.99      0.98      1787
# Attrited Customer       0.95      0.86      0.90       340
#
#          accuracy                           0.97      2127
#         macro avg       0.96      0.93      0.94      2127
#      weighted avg       0.97      0.97      0.97      2127
#
#            label  accuracy  precision  recall     F1   tp    fp  fn    tn  pred_pos  pred_neg  act_pos  act_neg  total
# 0    threshold_0     0.160      0.160   1.000  0.276  340  1787   0     0      2127         0      340     1787   2127
# ...

# %%
#catboost offers the greatest ROC curve and opportunity to achieve high 90% recall depending on threshold

# %%
# %run final-model.ipynb
# Out:
# Validation results
# 0:	learn: 0.5687521	total: 62.6ms	remaining: 1m 2s
# 200:	learn: 0.0320151	total: 17.4s	remaining: 1m 8s
# 400:	learn: 0.0145590	total: 35.5s	remaining: 53.1s
# 600:	learn: 0.0082167	total: 53.6s	remaining: 35.6s
# 800:	learn: 0.0052389	total: 1m 11s	remaining: 17.8s
# 999:	learn: 0.0039867	total: 1m 29s	remaining: 0us
#                    precision    recall  f1-score   support
#
# Existing Customer       0.98      0.99      0.99      2550
# Attrited Customer       0.94      0.91      0.92       488
#
#          accuracy                           0.98      3038
#         macro avg       0.96      0.95      0.95      3038
#      weighted avg       0.98      0.98      0.98      3038
#
#            label  accuracy  precision  recall     F1   tp    fp   fn    tn  pred_pos  pred_neg  act_pos  act_neg  total
# 0    threshold_0     0.161      0.161   1.000  0.277  488  2550    0     0      3038         0      488     2550   3038
# ...
